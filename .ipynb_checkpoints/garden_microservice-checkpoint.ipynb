# %%
app = Flask(__name__)

@app.route("/weather", methods=["GET"])
def GET_weather():
    return 0

@app.route("/alerts", methods=["GET"])
def GET_alerts():
    return 0

@app.route("/analysis/<mode>", methods=["GET"])
def GET_analysis(mode):
    if mode==:
    
    return 0

# %%
from flask import Flask, render_template, request, jsonify
import os
import requests
from datetime import datetime, timedelta, time
import re
from dotenv import load_dotenv
import datetime

# %%
api="https://api.openweathermap.org/data/2.5/onecall?lat=40.11&lon=-88.24&appid=d2a3dae5495f90d6b1847e4480770e65"

# %%
weather_data = requests.get(
   api
).json()

try:
    daily_data = weather_data['daily']
except:
    daily_data = "unavailable"
    
def willRain(forecast):
    if daily_data=="unavailable":
        return 0
    else:
        
    
willRain(daily_data)

# %%
weather_data['daily'][0]['pop']
# Out:
# 0.36

# %%
weather_data
# Out:
# {'lat': 40.11,
#  'lon': -88.24,
#  'timezone': 'America/Chicago',
#  'timezone_offset': -18000,
#  'current': {'dt': 1652111273,
#   'sunrise': 1652093005,
#   'sunset': 1652144125,
#   'temp': 292.75,
#   'feels_like': 292.62,
#   'pressure': 1008,
#   'humidity': 71,
#   'dew_point': 287.35,
#   'uvi': 5.84,
#   'clouds': 100,
#   'visibility': 10000,
#   'wind_speed': 7.72,
#   'wind_deg': 140,
#   'wind_gust': 12.35,
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}]},
#  'minutely': [{'dt': 1652111280, 'precipitation': 0},
#   {'dt': 1652111340, 'precipitation': 0},
#   {'dt': 1652111400, 'precipitation': 0},
#   {'dt': 1652111460, 'precipitation': 0},
#   {'dt': 1652111520, 'precipitation': 0},
#   {'dt': 1652111580, 'precipitation': 0},
#   {'dt': 1652111640, 'precipitation': 0},
#   {'dt': 1652111700, 'precipitation': 0},
#   {'dt': 1652111760, 'precipitation': 0},
#   {'dt': 1652111820, 'precipitation': 0},
# ...

# %%
datetime.datetime.fromtimestamp(1652634000)
# Out:
# datetime.datetime(2022, 5, 15, 12, 0)

# %%
# the .rain is not always there

# %%
daily_data
# Out:
# [{'dt': 1652115600,
#   'sunrise': 1652093005,
#   'sunset': 1652144125,
#   'moonrise': 1652118480,
#   'moonset': 1652081820,
#   'moon_phase': 0.27,
#   'temp': {'day': 293.81,
#    'min': 286.53,
#    'max': 297.31,
#    'night': 292.3,
#    'eve': 295.62,
#    'morn': 286.65},
#   'feels_like': {'day': 293.84,
#    'night': 292.65,
#    'eve': 295.91,
#    'morn': 286.14},
#   'pressure': 993,
#   'humidity': 73,
#   'dew_point': 288.8,
#   'wind_speed': 10.04,
#   'wind_deg': 168,
#   'wind_gust': 16.22,
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'clouds': 98,
#   'pop': 0.36,
#   'rain': 0.55,
#   'uvi': 7.94},
#  {'dt': 1652202000,
#   'sunrise': 1652179342,
#   'sunset': 1652230584,
#   'moonrise': 1652208780,
#   'moonset': 1652169900,
#   'moon_phase': 0.3,
#   'temp': {'day': 301.04,
#    'min': 290.82,
#    'max': 303.21,
#    'night': 295.56,
#    'eve': 301.91,
#    'morn': 290.82},
# ...
